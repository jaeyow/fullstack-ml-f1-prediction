# %%
! pip install duckdb
# Out:
# Collecting duckdb
#   Obtaining dependency information for duckdb from https://files.pythonhosted.org/packages/d7/de/134a8310d18166f1ceb915038259bc0a0bb538d5f4d5a43bfc9632282486/duckdb-0.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading duckdb-0.9.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (760 bytes)
# Downloading duckdb-0.9.2-cp311-cp311-macosx_11_0_arm64.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 8.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: duckdb
# Successfully installed duckdb-0.9.2

# %%
import duckdb

drivers_df = duckdb.sql(
	"""
	SELECT
  	drivers.driverId,
  	drivers.surname,
    drivers.forename,
    standings.points,
    races.name,
    races.year
	FROM '../data/drivers.csv' as drivers
	INNER JOIN '../data/driver_standings.csv' as standings
  	ON drivers.driverId = standings.driverId
  INNER JOIN '../data/races.csv' as races
		ON standings.raceId = races.raceId
	WHERE surname = 'Ricciardo' AND standings.position <= 5
	ORDER BY standings.points DESC
	"""
  ).to_df()
drivers_df
# Out:
#     driverId    surname forename  points                      name  year
# 0        817  Ricciardo   Daniel   256.0      Abu Dhabi Grand Prix  2016
# 1        817  Ricciardo   Daniel   246.0      Brazilian Grand Prix  2016
# 2        817  Ricciardo   Daniel   242.0        Mexican Grand Prix  2016
# 3        817  Ricciardo   Daniel   238.0      Abu Dhabi Grand Prix  2014
# 4        817  Ricciardo   Daniel   227.0  United States Grand Prix  2016
# ..       ...        ...      ...     ...                       ...   ...
# 64       817  Ricciardo   Daniel    36.0        Chinese Grand Prix  2016
# 65       817  Ricciardo   Daniel    36.0        Russian Grand Prix  2016
# 66       817  Ricciardo   Daniel    24.0        Bahrain Grand Prix  2016
# 67       817  Ricciardo   Daniel    12.0     Australian Grand Prix  2016
# 68       817  Ricciardo   Daniel    12.0     Australian Grand Prix  2018
#
# [69 rows x 6 columns]
